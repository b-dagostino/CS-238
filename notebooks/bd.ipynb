# %%
In [1]: %load_ext kedro.ipython
# Out:
# [11/11/25 13:14:32] INFO     Using                                                                  __init__.py:270
#                              'c:\BrainStem\local\Work\Academic\Stanford\School\Courses\2025-Q4-Autu
#                              mn\CS 238 - Decision Making Under Uncertainty\Final
#                              Project\.venv\Lib\site-packages\kedro\framework\project\rich_logging.y
#                              ml' as logging configuration.
#                     INFO     Registered line magic '%reload_kedro'                                   __init__.py:63
#                     INFO     Registered line magic '%load_node'                                      __init__.py:65
#                     INFO     Resolved project path as:                                              __init__.py:180
#                              c:\BrainStem\local\Work\Academic\Stanford\School\Courses\2025-Q4-Autum
#                              n\CS 238 - Decision Making Under Uncertainty\Final Project.
#                              To set a different path, run '%reload_kedro <project_root>'
# [11/11/25 13:14:35] INFO     Kedro is sending anonymous usage data with the sole purpose of improving plugin.py:243
#                              the product. No personal data or IP addresses are stored on our side. To
#                              opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK` environment
#                              variables, or create a `.telemetry` file in the current working
#                              directory with the contents `consent: false`. To hide this message,
#                              explicitly grant or deny consent. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
#                     INFO     Kedro project CS 238                                                   __init__.py:146
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            __init__.py:147
#                              'pipelines'
# [11/11/25 13:14:36] INFO     Registered line magic 'run_viz'                                        __init__.py:153

# %%
alarms = catalog.load("clean_alarms")
status = catalog.load("clean_station_overviews")
sessions = catalog.load("clean_charging_sessions")

sn_map = catalog.load("map_serial_number")
ss_map = catalog.load("map_station_status")
ns_map = catalog.load("map_network_status")
a_map = catalog.load("map_alarm")
# Out:
#                     INFO     Loading data from clean_alarms (ParquetDataset)...                data_catalog.py:1046
#                     INFO     Loading data from clean_station_overviews (ParquetDataset)...     data_catalog.py:1046
#                     INFO     Loading data from clean_charging_sessions (ParquetDataset)...     data_catalog.py:1046
# [11/11/25 13:14:37] INFO     Loading data from map_serial_number (ParquetDataset)...           data_catalog.py:1046
#                     INFO     Loading data from map_station_status (ParquetDataset)...          data_catalog.py:1046
#                     INFO     Loading data from map_network_status (ParquetDataset)...          data_catalog.py:1046
#                     INFO     Loading data from map_alarm (ParquetDataset)...                   data_catalog.py:1046

# %%
domain_alarms = catalog.load("domain_alarms")
domain_status = catalog.load("domain_status")
# domain = catalog.load("domain_alarms")
# Out:
# [11/11/25 13:15:22] INFO     Loading data from domain_alarms (ParquetDataset)...               data_catalog.py:1046
#                     INFO     Loading data from domain_status (ParquetDataset)...               data_catalog.py:1046

# %%
domain_alarms, domain_status
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# (
#                                    aid
# cid timestamp
# 1   2018-04-10 20:08:55+00:00    5
#     2018-04-11 16:55:02+00:00    3
#     2018-04-12 04:26:09+00:00    4
#     2018-04-13 06:05:06+00:00    3
#     2018-04-13 06:12:41+00:00    4
# ...                            ...
# 141 2021-09-25 13:26:12+00:00   32
#     2021-09-25 13:29:20+00:00   20
#     2021-09-25 13:29:20+00:00   20
#     2021-09-25 14:05:08+00:00    3
#     2024-01-18 10:47:36+00:00    3
#
# [515050 rows x 1 columns],
#                                           ssid  nsid
# cid timestamp
# 1   2025-04-23 22:03:10.345619+00:00     1     1
#     2025-04-24 00:29:46.558792+00:00     1     1
#     2025-04-24 01:29:47.057004+00:00     1     1
#     2025-04-24 02:29:46.288501+00:00     2     1
#     2025-04-24 03:29:45.839639+00:00     2     1
# ...                                    ...   ...
# 141 2025-07-15 06:44:28.503578+00:00     3     2
#     2025-07-15 08:44:26.898087+00:00     3     2
#     2025-07-15 09:44:28.412517+00:00     3     2
#     2025-07-15 11:44:28.774299+00:00     3     2
#     2025-07-15 13:44:26.566200+00:00     3     2
#
# [273091 rows x 2 columns]
# )

# %%
a_map
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                     id
# Circuit Sharing Current Reduced                      1
# Circuit Sharing Current Restored                     2
# Unreachable                                          3
# Reachable                                            4
# Bootup Due to SOFT RESET                             5
# Bootup Due to WATCHDOG                               6
# Powered Off                                          7
# Boot up                                              8
# Unknown RFID                                         9
# Pilot Unreachable (18)                              10
# IP Mismatch Detected                                11
# Bootup Due to SWITCH                                12
# Tamper Detect                                       13
# Station Not Activated                               14
# Maintenance Required                                15
# Hardware Fault                                      16
# Hardware Fault Station Out Of Service               17
# Relay Stuck Close                                   18
# GFCI Soft Trip                                      19
# Fault Cleared                                       20
# Bootup Due to POWER ON                              21
# Data Partition Full                                 22
# Emergency Stop button pressed - No circuit brea...  23
# EVSE Unreachable                                    24
# Charger Fault - contact Tritium (28)                25
# FCheck Error                                        26
# Vehicle fault (50)                                  27
# 7fff                                                28
# Communication timeout. (62)                         29
# Communication timeout. (63)                         30
# RFID Update Failed                                  31
# CHAdeMO control loop detected fault (39)            32
# Ventilation Fault                                   33
# Earth Fault Station In Service                      34
# Earth Fault Station Out Of Service                  35
# Pilot current level exceeded                        36
# Grace Sessions Exceeded                             37
# GFCI Hard Trip                                      38
# Over Current Hard Trip Detected                     39
# Manual Intervention                                 40

# %%
R(s, a)
    if faulted / unreachable, but we do nothing: -100
    if are not faulted, and we alert: -50
    if faulted, and we already alerted in the last xxx time, and then we alert again: -10
    else (we did good): +10
